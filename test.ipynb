# %%
import os
from dotenv import load_dotenv
load_dotenv()  # reads .env from the current working directory by default

print("Key loaded:", bool(os.environ.get("ANTHROPIC_API_KEY")))
print("LLM loaded:", (os.environ.get("LLM_BACKEND")))
# Out:
# Key loaded: True
# LLM loaded: anthropic
